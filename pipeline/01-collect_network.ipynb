# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import networkx as nx
from tqdm.auto import tqdm

import src
from src.google.request import YtRequestor
from src.google.utils import extract_info, run_step, create_network

# %%
tube = YtRequestor()

# %%
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_rows", 256)

# %%
N_SEARCH_RESULTS = 1000
N_RECOMMENDATIONS = 50

SEARCH_STRING = "vaccine mandate"

# %%
results = tube.search(SEARCH_STRING, max_results=N_SEARCH_RESULTS)

# %%
len(results)
# Out:
# 596

# %%
df = extract_info(pd.DataFrame(results))
df["step"] = 0
df["source_video_id"] = None

# %%
df2 = run_step(tube, df, max_results=N_RECOMMENDATIONS)
# Out:
#   0%|          | 0/548 [00:00<?, ?it/s]
# [14:49:01.121] Switching key (units=100) after 102 uses. 23 keys left
# [14:49:01.295] Switching key (units=100) after 1 uses. 22 keys left
# [14:50:30.969] Switching key (units=100) after 101 uses. 21 keys left
# [14:51:59.530] Switching key (units=100) after 101 uses. 20 keys left
# [14:51:59.723] Switching key (units=100) after 1 uses. 19 keys left
# [14:51:59.907] Switching key (units=100) after 1 uses. 18 keys left
# [14:53:28.722] Switching key (units=100) after 101 uses. 17 keys left
# [14:55:00.041] Switching key (units=100) after 102 uses. 16 keys left
# [14:55:00.213] Switching key (units=100) after 1 uses. 15 keys left
# [14:55:00.383] Switching key (units=100) after 1 uses. 14 keys left
# [14:55:00.546] Switching key (units=100) after 1 uses. 13 keys left
# [14:55:00.686] Switching key (units=100) after 1 uses. 12 keys left
# [14:55:00.837] Switching key (units=100) after 1 uses. 11 keys left
# [14:56:30.119] Switching key (units=100) after 101 uses. 10 keys left
# [14:56:30.288] Switching key (units=100) after 1 uses. 9 keys left
# [14:56:30.455] Switching key (units=100) after 1 uses. 8 keys left
# [14:56:30.758] Switching key (units=100) after 1 uses. 7 keys left

# %%
g = create_network(df2)

# %%
len(g.nodes())
# Out:
# 14488

# %%
len(g.edges())
# Out:
# 27000

# %%
filename = SEARCH_STRING.replace(" ", "_")

nx.write_gml(g, src.PATH / f"data/interim/networks/{filename}.gml")
