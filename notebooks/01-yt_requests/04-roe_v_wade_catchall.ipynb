# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import networkx as nx
from tqdm.auto import tqdm

import src
from src.google.request import YtRequestor
from src.google.utils import extract_info, run_step, create_network

# %%
pd.set_option("max_colwidth", 256)

# %%
N_SEARCH_RESULTS = 1000
N_RECOMMENDATIONS = 50

# %%
tube = YtRequestor()
results = tube.search("roe v wade", max_results=N_SEARCH_RESULTS)
# Out:
# [17:22:58.007] Switching key from AIzaSyA-7KzExoQB0jqT0xQcAN8pPYDBytuhvUA to AIzaSyA-owXRCenDucXDI4ljBZYztv9BSAAf0co
# [17:22:58.114] Switching key from AIzaSyA-owXRCenDucXDI4ljBZYztv9BSAAf0co to AIzaSyDdDzi4AHAZe8xYX47S2BeZkcww8NBlg9s
# [17:22:58.323] Switching key from AIzaSyDdDzi4AHAZe8xYX47S2BeZkcww8NBlg9s to AIzaSyAJk5WHQPrNyqFgso6vFS5DThdQwrW0GlE
# [17:22:58.393] Switching key from AIzaSyAJk5WHQPrNyqFgso6vFS5DThdQwrW0GlE to AIzaSyCxeN2DQiJa0uTkue3J-aNh1TGE9OM4BFE
# [17:22:58.443] Switching key from AIzaSyCxeN2DQiJa0uTkue3J-aNh1TGE9OM4BFE to AIzaSyBNRmIrsvoLE4l6d_OHmrbWemJz1rEI-1w
# [17:22:58.657] Switching key from AIzaSyBNRmIrsvoLE4l6d_OHmrbWemJz1rEI-1w to AIzaSyB6wHlTy71Qmn1ojMvrNmuZPIsGfVFDc7o
# [17:23:06.230] Switching key from AIzaSyB6wHlTy71Qmn1ojMvrNmuZPIsGfVFDc7o to AIzaSyCooJupsv0mShbXVvI4N1eyvT9gdw3E6xQ

# %%
len(results)
# Out:
# 555

# %%
df = extract_info(pd.DataFrame(results))
df["step"] = 0
df["source_video_id"] = None

# %%
df2 = run_step(tube, df, max_results=50)
# Out:
#   0%|          | 0/531 [00:00<?, ?it/s]
# [17:23:52.571] Switching key from AIzaSyCooJupsv0mShbXVvI4N1eyvT9gdw3E6xQ to AIzaSyCgqMYoQ3mGiYKiKhu9ZNzevuCTZoF-pL4
# [17:24:34.632] Switching key from AIzaSyCgqMYoQ3mGiYKiKhu9ZNzevuCTZoF-pL4 to AIzaSyCRpZeucerkVOa8rrxhJs6qxde1laIWUSk
# [17:25:14.539] Switching key from AIzaSyCRpZeucerkVOa8rrxhJs6qxde1laIWUSk to AIzaSyDQI1DJxxWFZn2jkDF7uzmnuninu6eWVPE
# [17:25:55.089] Switching key from AIzaSyDQI1DJxxWFZn2jkDF7uzmnuninu6eWVPE to AIzaSyDgaXbOh0wO7U0Tzi_8LWtliAsdbleYvAQ
# [17:26:34.369] Switching key from AIzaSyDgaXbOh0wO7U0Tzi_8LWtliAsdbleYvAQ to AIzaSyB27WvmJiRhvPMztFIbYIi1O7dK04hmWgM
# [17:27:17.524] Switching key from AIzaSyB27WvmJiRhvPMztFIbYIi1O7dK04hmWgM to AIzaSyApBYyzEXLMci_vUILf2gJaG9qxflcnNZo
# [17:27:59.484] Switching key from AIzaSyApBYyzEXLMci_vUILf2gJaG9qxflcnNZo to AIzaSyA4WcBZqQugmwZeOKVWotbyzAFzlNutxjM
# [17:28:43.946] Switching key from AIzaSyA4WcBZqQugmwZeOKVWotbyzAFzlNutxjM to AIzaSyCSi1bYEL4hjKvbn5o0QhWnhg3xu7hAdgA
# ...

# %%
g = create_network(df2)

# %%
len(g.nodes())
# Out:
# 531

# %%
len(g.edges())
# Out:
# 4175

# %%
df2["step"].value_counts()
# Out:
# 1    26185
# 0      555
# Name: step, dtype: int64

# %%
df.shape
# Out:
# (555, 11)

# %%
df2.shape
# Out:
# (26740, 12)

# %%
df2.iloc[:, 4:].to_csv(src.PATH / "data/raw/roe_v_wade_catch_all.csv")

# %%
import networkx as nx

nx.write_gml(g, src.PATH / "data/interim/networks/roe_v_wade_full.gml")

# %%
r = tube.get_recommended_videos("zDztJN9-o4c", max_results=50)

# %%
r
# Out:
# [{'kind': 'youtube#searchResult',
#   'etag': 'IHLNS4XTjcHtwDL1dbiQzQ2Ds3k',
#   'id': {'kind': 'youtube#video', 'videoId': 'zDztJN9-o4c'},
#   'snippet': {'publishedAt': '2022-06-24T14:53:18Z',
#    'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#    'title': 'Supreme Court Overturns Roe v. Wade, Breaking Nearly 50 Years Of Precedence',
#    'description': 'The Supreme Court has overturned Roe v. Wade, a 1973 landmark ruling that protected the right to abortion nationwide, breaking ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zDztJN9-o4c/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/zDztJN9-o4c/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/zDztJN9-o4c/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'MSNBC',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-06-24T14:53:18Z'}}]
