# %%
from src.google.request import YtRequestor

# %% [markdown]
# # How to use youtube

# %%
# create a keys.txt in the toplevel
tube = YtRequestor()

# %%
response = tube.get_recommended_videos(video_id="6RxqNv6bEug")
# Out:
# [16:47:36.152] Switching key from test to AIzaSyA-7KzExoQB0jqT0xQcAN8pPYDBytuhvUA

# %%
# items will contain all recommendation
print(response.keys())
# Out:
# dict_keys(['kind', 'etag', 'nextPageToken', 'regionCode', 'pageInfo', 'items'])
