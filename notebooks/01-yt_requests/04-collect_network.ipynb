# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import networkx as nx
from tqdm.auto import tqdm

import src
from src.google.request import YtRequestor
from src.google.utils import extract_info, run_step, create_network

# %%
tube = YtRequestor()

# %%
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_rows", 256)

# %%
N_SEARCH_RESULTS = 1000
N_RECOMMENDATIONS = 50

SEARCH_STRING = "vintage jewelry"

# %%
results = tube.search(SEARCH_STRING, max_results=N_SEARCH_RESULTS)

# %%
len(results)
# Out:
# 596

# %%
df = extract_info(pd.DataFrame(results))
df["step"] = 0
df["source_video_id"] = None

# %%
df2 = run_step(tube, df, max_results=N_RECOMMENDATIONS)
# Out:
#   0%|          | 0/576 [00:00<?, ?it/s]
# [15:28:12.047] Switching key (units=100) after 103 uses. 10 keys left
# [15:28:59.030] Switching key (units=100) after 102 uses. 9 keys left
# [15:29:51.060] Switching key (units=100) after 102 uses. 8 keys left
# [15:29:51.265] Switching key (units=100) after 1 uses. 7 keys left
# [15:30:40.119] Switching key (units=100) after 101 uses. 6 keys left
# [15:31:30.810] Switching key (units=100) after 103 uses. 5 keys left
# [15:31:30.860] Switching key (units=100) after 1 uses. 4 keys left
# [15:31:31.117] Switching key (units=100) after 1 uses. 3 keys left

# %%
g = create_network(df2)

# %%
len(g.nodes())

# %%
len(g.edges())

# %%
filename = SEARCH_STRING.replace(" ", "_")

nx.write_gml(g, src.PATH / f"data/interim/networks/{filename}.gml")
