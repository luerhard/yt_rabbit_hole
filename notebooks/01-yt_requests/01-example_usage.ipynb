# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.google.request import YtRequestor

# %%
# create a keys.txt in the root directory of this repository
tube = YtRequestor()

# %% [markdown]
# # How to use youtube

# %%
response = tube.get_recommended_videos(video_id="6RxqNv6bEug")
# Out:
# [12:07:10.796] Switching key from test to AIzaSyA-7KzExoQB0jqT0xQcAN8pPYDBytuhvUA

# %%
# items will contain all recommendations
print(response.keys())
# Out:
# dict_keys(['kind', 'etag', 'nextPageToken', 'regionCode', 'pageInfo', 'items'])

# %% [markdown]
# # How to search

# %%
len(tube.search("COVID")["items"])
# Out:
# 50
